# %%
import pandas as pd

data = pd.read_csv("data_origin/Culture Offensive Words - Sheet5.csv")
data
# Out:
#           culture    word_category  \
# 0         Chinese         noun.act
# 1         Chinese      noun.animal
# 2         Chinese    noun.artifact
# 3         Chinese   noun.attribute
# 4         Chinese        noun.body
# ..            ...              ...
# 315  Christianity  verb.perception
# 316  Christianity  verb.possession
# 317  Christianity      verb.social
# 318  Christianity     verb.stative
# 319  Christianity     verb.weather
#
#                                            word_1  \
# 0                               Insulting symbols
# 1                                           Panda
# 2                                           Opium
# 3    Create brands or products using the number 4
# 4                                            Feet
# ..                                            ...
# 315                                     Blaspheme
# 316                                    Worshiping
# 317                                     Blaspheme
# ...

# %%
subset_data = data.loc[data["culture"] == "Chinese"]
subset = []
for i in range(len(subset_data)):
    dataline = subset_data.loc[i]
    data_culture = dataline[0]
    data_category = dataline[1]
    for word in dataline.iloc[2:]:
        subset.append([data_culture, data_category, word])
# Out:
# C:\Users\nagis\AppData\Local\Temp\ipykernel_39780\1918302939.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_culture = dataline[0]
# C:\Users\nagis\AppData\Local\Temp\ipykernel_39780\1918302939.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_category = dataline[1]

# %%
data_clean = pd.DataFrame(subset, columns=["culture", "word_category", "word"])
data_clean["Annotation"] = ""
data_clean
# Out:
#      culture word_category                  word Annotation
# 0    Chinese      noun.act     Insulting symbols
# 1    Chinese      noun.act  Disrespecting elders
# 2    Chinese      noun.act         Public nudity
# 3    Chinese      noun.act             Littering
# 4    Chinese      noun.act              Spitting
# ..       ...           ...                   ...        ...
# 395  Chinese  verb.weather                 Sleet
# 396  Chinese  verb.weather               Tornado
# 397  Chinese  verb.weather               Drought
# 398  Chinese  verb.weather               Blister
# 399  Chinese  verb.weather               Swelter
#
# [400 rows x 4 columns]

# %%
data_clean.to_csv("data_clean/Culture Offensive Word - Chinese.csv", index=False)
